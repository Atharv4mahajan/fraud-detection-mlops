# %%
import os
print(os.getenv("MONGODB_URL"))
# Out:
# None

# %%
from pymongo import MongoClient

MONGODB_URL = "mongodb+srv://athumahajan04_db_user:yMsrClJP3iOAo1Nh@cluster0.0gnjcyl.mongodb.net/?appName=Cluster0"

client = MongoClient(MONGODB_URL)
print(client.list_database_names())
# Out:
# ['admin', 'local']

# %%
import pandas as pd

df = pd.read_csv("creditcard.csv")

database = client["fraud_database"]
collection = database["fraud_data"]

records = df.to_dict(orient="records")

batch_size = 10000
for i in range(0, len(records), batch_size):
    collection.insert_many(records[i:i+batch_size])

print("Data pushed successfully")
# Out:
# Data pushed successfully
